# %%
# %matplotlib inline
import pandas as pd
import scipy as sp
import numpy as np
import  statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import statsmodels.api as sm
from patsy import dmatrices

# %%
# 一元线性回归分析方法
data = pd.DataFrame({"X":np.arange(10,20,0.25)})
data["Y"] = 2 * data["X"] + 1 + np.random.randn(40)
mod = smf.ols("Y ~ X", data).fit()
mod.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      Y   R-squared:                       0.971
# Model:                            OLS   Adj. R-squared:                  0.970
# Method:                 Least Squares   F-statistic:                     1276.
# Date:                Wed, 15 Mar 2023   Prob (F-statistic):           7.53e-31
# Time:                        17:32:14   Log-Likelihood:                -57.629
# No. Observations:                  40   AIC:                             119.3
# Df Residuals:                      38   BIC:                             122.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2970      0.871      0.341      0.735      -1.465       2.059
# X              2.0524      0.057     35.724      0.000       1.936       2.169
# ==============================================================================
# Omnibus:                        1.136   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.567   Jarque-Bera (JB):                0.716
# Skew:                          -0.327   Prob(JB):                        0.699
# Kurtosis:                       3.021   Cond. No.                         79.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
data.plot(x="X", y="Y",kind="scatter",figsize=(8,5))
plt.plot(data["X"], mod.params[0] + mod.params[1]*data["X"],"r")
plt.text(10, 38, "y="+str(round(mod.params[1],4)) + "*x" + str(round(mod.params[0],4)))
plt.title("linear regression")
plt.show()

# %%
df = pd.read_csv("data/sample.csv")
df = df.dropna()
